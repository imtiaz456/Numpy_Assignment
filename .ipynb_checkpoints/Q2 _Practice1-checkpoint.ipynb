# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv("D:\\jupyter\\github_data from book\\astronauts.csv")

# %%
data
# Out:
#                       name  year  group   status        dob  \
# 0          Joseph M. Acaba  2004     19   Active  5/17/1967
# 1           Loren W. Acton  1985     10  Retired   3/7/1936
# 2         James C. Adamson  1984     10  Retired   3/3/1946
# 3          Thomas D. Akers  1987     12  Retired  5/20/1951
# 4              Buzz Aldrin  1963      3  Retired  1/20/1930
# ..                     ...   ...    ...      ...        ...
# 352          David A. Wolf  1990     13  Retired  8/23/1956
# 353  Neil W. Woodward III   1998     17  Retired  7/26/1962
# 354       Alfred M. Worden  1966      5  Retired   2/7/1932
# 355          John W. Young  1962      2  Retired  9/24/1930
# 356        George D. Zamka  1998     17  Retired  6/29/1962
#
#             birthplace gender                              alma_mater  \
# 0        Inglewood, CA   Male  University of California-Santa Barbara
# 1         Lewiston, MT   Male                Montana State University
# ...

# %%
data.shape
# Out:
# (357, 13)

# %%
data.describe()
# Out:
#               year       group  spaceflights  spaceflight_hours  spacewalks  \
# count   357.000000  357.000000    357.000000         357.000000  357.000000
# mean   1985.403361   11.498599      2.364146        1249.266106    1.246499
# std      12.821803    5.007648      1.428700        1896.759857    2.056989
# min    1959.000000    1.000000      0.000000           0.000000    0.000000
# 25%    1978.000000    8.000000      1.000000         289.000000    0.000000
# 50%    1987.000000   12.000000      2.000000         590.000000    0.000000
# 75%    1996.000000   16.000000      3.000000        1045.000000    2.000000
# max    2009.000000   20.000000      7.000000       12818.000000   10.000000
#
#        spacewalk_hours
# count       357.000000
# mean          7.711485
# std          13.365779
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          12.000000
# max          67.000000

# %%
data.columns
# Out:
# Index(['name', 'year', 'group', 'status', 'dob', 'birthplace', 'gender',
#        'alma_mater', 'spaceflights', 'spaceflight_hours', 'spacewalks',
#        'spacewalk_hours', 'missions'],
#       dtype='object')

# %%
data.name
# Out:
# 0            Joseph M. Acaba
# 1             Loren W. Acton
# 2           James C. Adamson
# 3            Thomas D. Akers
# 4                Buzz Aldrin
#                ...
# 352            David A. Wolf
# 353    Neil W. Woodward III
# 354         Alfred M. Worden
# 355            John W. Young
# 356          George D. Zamka
# Name: name, Length: 357, dtype: object

# %%
data.year
# Out:
# 0      2004
# 1      1985
# 2      1984
# 3      1987
# 4      1963
#        ...
# 352    1990
# 353    1998
# 354    1966
# 355    1962
# 356    1998
# Name: year, Length: 357, dtype: int64

# %%
data.missions
# Out:
# 0                 STS-119 (Discovery), ISS-31/32 (Soyuz)
# 1                                  STS 51-F (Challenger)
# 2                   STS-28 (Columbia), STS-43 (Atlantis)
# 3      STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...
# 4                                   Gemini 12, Apollo 11
#                              ...
# 352    STS-58 (Columbia). STS-86/89 (Atlantis/Endeavo...
# 353                                                  NaN
# 354                                            Apollo 15
# 355    Gemini 3, Gemini 10, Apollo 10, Apollo 16, STS...
# 356              STS-120 (Discovery), STS-130 (Endeavor)
# Name: missions, Length: 357, dtype: object

# %%
data.notnull()
# Out:
#      name  year  group  status   dob  birthplace  gender  alma_mater  \
# 0    True  True   True    True  True        True    True        True
# 1    True  True   True    True  True        True    True        True
# 2    True  True   True    True  True        True    True        True
# 3    True  True   True    True  True        True    True        True
# 4    True  True   True    True  True        True    True        True
# ..    ...   ...    ...     ...   ...         ...     ...         ...
# 352  True  True   True    True  True        True    True        True
# 353  True  True   True    True  True        True    True        True
# 354  True  True   True    True  True        True    True        True
# 355  True  True   True    True  True        True    True        True
# 356  True  True   True    True  True        True    True        True
#
#      spaceflights  spaceflight_hours  spacewalks  spacewalk_hours  missions
# ...

# %%
data.head()
# Out:
#                name  year  group   status        dob     birthplace gender  \
# 0   Joseph M. Acaba  2004     19   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton  1985     10  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984     10  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987     12  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963      3  Retired  1/20/1930  Montclair, NJ   Male
#
#                                alma_mater  spaceflights  spaceflight_hours  \
# 0  University of California-Santa Barbara             2               3307
# 1                Montana State University             1                190
# 2                     US Military Academy             2                334
# 3            University of Missouri-Rolla             4                814
# 4                     US Military Academy             2                289
#
#    spacewalks  spacewalk_hours  \
# ...

# %%
data.alma_mater
# Out:
# 0      University of California-Santa Barbara
# 1                    Montana State University
# 2                         US Military Academy
# 3                University of Missouri-Rolla
# 4                         US Military Academy
#                         ...
# 352                         Purdue University
# 353                                       MIT
# 354                       US Military Academy
# 355           Georgia Institute of Technology
# 356                          US Naval Academy
# Name: alma_mater, Length: 357, dtype: object

# %%
data.tail()
# Out:
#                       name  year  group   status        dob  \
# 352          David A. Wolf  1990     13  Retired  8/23/1956
# 353  Neil W. Woodward III   1998     17  Retired  7/26/1962
# 354       Alfred M. Worden  1966      5  Retired   2/7/1932
# 355          John W. Young  1962      2  Retired  9/24/1930
# 356        George D. Zamka  1998     17  Retired  6/29/1962
#
#             birthplace gender                       alma_mater  spaceflights  \
# 352   Indianapolis, IN   Male                Purdue University             3
# 353        Chicago, IL   Male                              MIT             0
# 354        Jackson, MI   Male              US Military Academy             1
# 355  San Francisco, CA   Male  Georgia Institute of Technology             6
# 356    Jersey City, NJ   Male                 US Naval Academy             2
#
#      spaceflight_hours  spacewalks  spacewalk_hours  \
# 352               4044           7               41
# ...

# %%
data.notnull().count()
# Out:
# name                 357
# year                 357
# group                357
# status               357
# dob                  357
# birthplace           357
# gender               357
# alma_mater           357
# spaceflights         357
# spaceflight_hours    357
# spacewalks           357
# spacewalk_hours      357
# missions             357
# dtype: int64

# %%
data.year
# Out:
# 0      2004
# 1      1985
# 2      1984
# 3      1987
# 4      1963
#        ...
# 352    1990
# 353    1998
# 354    1966
# 355    1962
# 356    1998
# Name: year, Length: 357, dtype: int64

# %%
data.year
# Out:
# 0      2004
# 1      1985
# 2      1984
# 3      1987
# 4      1963
#        ...
# 352    1990
# 353    1998
# 354    1966
# 355    1962
# 356    1998
# Name: year, Length: 357, dtype: int64

# %%
data.group
# Out:
# 0      19
# 1      10
# 2      10
# 3      12
# 4       3
#        ..
# 352    13
# 353    17
# 354     5
# 355     2
# 356    17
# Name: group, Length: 357, dtype: int64

# %%
data.group.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 352    False
# 353    False
# 354    False
# 355    False
# 356    False
# Name: group, Length: 357, dtype: bool

# %%
data.head(1)
# Out:
#               name  year  group  status        dob     birthplace gender  \
# 0  Joseph M. Acaba  2004     19  Active  5/17/1967  Inglewood, CA   Male
#
#                                alma_mater  spaceflights  spaceflight_hours  \
# 0  University of California-Santa Barbara             2               3307
#
#    spacewalks  spacewalk_hours                                missions
# 0           2               13  STS-119 (Discovery), ISS-31/32 (Soyuz)

# %%
data.columns
# Out:
# Index(['name', 'year', 'group', 'status', 'dob', 'birthplace', 'gender',
#        'alma_mater', 'spaceflights', 'spaceflight_hours', 'spacewalks',
#        'spacewalk_hours', 'missions'],
#       dtype='object')

# %%
data.alma_mater.value_counts()
# Out:
# US Naval Academy                    52
# US Air Force Academy                38
# US Military Academy                 18
# Purdue University                   15
# MIT                                 12
#                                     ..
# Texas A&M University                 1
# Cambridge University                 1
# Washington State University          1
# LeMoyne College                      1
# Rensselaer Polytechnic Institute     1
# Name: alma_mater, Length: 145, dtype: int64

# %%
data.alma_mater.unique()
# Out:
# array(['University of California-Santa Barbara',
#        'Montana State University', 'US Military Academy',
#        'University of Missouri-Rolla', 'Villanova University',
#        'DePauw University', 'University of Illinois', 'US Naval Academy',
#        'Hastings College', 'University of Washington', 'MIT',
#        'Harvard University', 'University of Illinois-Urbana',
#        'Purdue University', 'Frostburg State University',
#        'University of Idaho', 'George Washington University',
#        'Drexel University', 'State University of New York-Buffalo',
#        'University of Texas', 'Cornell University', 'Lehigh University',
#        'Texas Technological College', 'Washington University',
#        'US Air Force Academy', 'Pennsylvania State University',
#        'University of North Carolina at Chapel Hill',
#        'University of Colorado', 'University of Wisconsin', 'The Citadel',
#        'College of William & Mary', 'Rice University',
# ...

# %%
data[data.missions.isnull()]   # we can filter the exact values
# Out:
#                             name  year  group      status         dob  \
# 17               Serena M. Aunon  2009     20      Active    4/9/1976
# 24        Charles A. Bassett II   1963      3    Deceased  12/30/1931
# 46                  John S. Bull  1966      5    Deceased   9/25/1934
# 50               Yvonne D. Cagle  1996     16  Management   4/24/1959
# 51             Fernando Caldeiro  1996     16    Deceased   6/12/1958
# 66             Philip K. Chapman  1967      6     Retired    3/5/1935
# 101             Jeanette J. Epps  2009     20      Active   11/3/1970
# 108              Jack D. Fischer  2009     20      Active   1/23/1974
# 116          Theodore C. Freeman  1963      3    Deceased   2/18/1930
# 129        Edward G. Givens Jr.   1966      5    Deceased    1/5/1930
# 136           Duane E. Graveline  1965      4     Retired    3/2/1931
# 165          Donald L. Holmquest  1967      6     Retired    4/7/1939
# ...

# %% [markdown]
# # Handling missing values
#   - filling missing values
#   - Dropping missing values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               357 non-null    object
#  1   year               357 non-null    int64
#  2   group              357 non-null    int64
#  3   status             357 non-null    object
#  4   dob                357 non-null    object
#  5   birthplace         357 non-null    object
#  6   gender             357 non-null    object
#  7   alma_mater         356 non-null    object
#  8   spaceflights       357 non-null    int64
#  9   spaceflight_hours  357 non-null    int64
#  10  spacewalks         357 non-null    int64
#  11  spacewalk_hours    357 non-null    int64
#  12  missions           334 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 36.4+ KB

# %%
data.year.fillna(data.year.mode(),inplace=True)

# %%
data.year.isnull().sum()
# Out:
# 0

# %%
data.columns
# Out:
# Index(['name', 'year', 'group', 'status', 'dob', 'birthplace', 'gender',
#        'alma_mater', 'spaceflights', 'spaceflight_hours', 'spacewalks',
#        'spacewalk_hours', 'missions'],
#       dtype='object')

# %%
data[data.alma_mater.isnull()]
# Out:
#                  name  year  group   status        dob  birthplace gender  \
# 155  Thomas J. Hennen  1991     13  Retired  8/17/1952  Albany, GA   Male
#
#     alma_mater  spaceflights  spaceflight_hours  spacewalks  spacewalk_hours  \
# 155        NaN             1                166           0                0
#
#               missions
# 155  STS-44 (Atlantis)

# %%
data[data.group.isnull()]
# Out:
# Empty DataFrame
# Columns: [name, year, group, status, dob, birthplace, gender, alma_mater, spaceflights, spaceflight_hours, spacewalks, spacewalk_hours, missions]
# Index: []

# %%
data.fillna({
    'year':data.year.mode(),
    'missions':data.missions.mode(),
    'birthplace':data.birthplace.mode()
})
# Out:
#                       name  year  group   status        dob  \
# 0          Joseph M. Acaba  2004     19   Active  5/17/1967
# 1           Loren W. Acton  1985     10  Retired   3/7/1936
# 2         James C. Adamson  1984     10  Retired   3/3/1946
# 3          Thomas D. Akers  1987     12  Retired  5/20/1951
# 4              Buzz Aldrin  1963      3  Retired  1/20/1930
# ..                     ...   ...    ...      ...        ...
# 352          David A. Wolf  1990     13  Retired  8/23/1956
# 353  Neil W. Woodward III   1998     17  Retired  7/26/1962
# 354       Alfred M. Worden  1966      5  Retired   2/7/1932
# 355          John W. Young  1962      2  Retired  9/24/1930
# 356        George D. Zamka  1998     17  Retired  6/29/1962
#
#             birthplace gender                              alma_mater  \
# 0        Inglewood, CA   Male  University of California-Santa Barbara
# 1         Lewiston, MT   Male                Montana State University
# ...

# %% [markdown]
# # Duplicate records

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 352    False
# 353    False
# 354    False
# 355    False
# 356    False
# Length: 357, dtype: bool

# %%
data.name.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 352    False
# 353    False
# 354    False
# 355    False
# 356    False
# Name: name, Length: 357, dtype: bool

# %%
data.iloc[356:,:]=np.nan

# %%
data.info
# Out:
# <bound method DataFrame.info of                       name    year  group   status        dob  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton  1985.0   10.0  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#             birthplace gender                              alma_mater  \
# 0        Inglewood, CA   Male  University of California-Santa Barbara
# ...

# %%
data.columns
# Out:
# Index(['name', 'year', 'group', 'status', 'dob', 'birthplace', 'gender',
#        'alma_mater', 'spaceflights', 'spaceflight_hours', 'spacewalks',
#        'spacewalk_hours', 'missions'],
#       dtype='object')

# %%
data.tail()
# Out:
#                       name    year  group   status        dob  \
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356                    NaN     NaN    NaN      NaN        NaN
#
#             birthplace gender                       alma_mater  spaceflights  \
# 352   Indianapolis, IN   Male                Purdue University           3.0
# 353        Chicago, IL   Male                              MIT           0.0
# 354        Jackson, MI   Male              US Military Academy           1.0
# 355  San Francisco, CA   Male  Georgia Institute of Technology           6.0
# 356                NaN    NaN                              NaN           NaN
#
#      spaceflight_hours  spacewalks  spacewalk_hours  \
# 352             4044.0         7.0             41.0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates(keep='last')
# Out:
#                       name    year  group   status        dob  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton  1985.0   10.0  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356                    NaN     NaN    NaN      NaN        NaN
#
#             birthplace gender                              alma_mater  \
# 0        Inglewood, CA   Male  University of California-Santa Barbara
# 1         Lewiston, MT   Male                Montana State University
# ...

# %%
data.drop_duplicates(subset=['name','missions'])
# Out:
#                       name    year  group   status        dob  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton  1985.0   10.0  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356                    NaN     NaN    NaN      NaN        NaN
#
#             birthplace gender                              alma_mater  \
# 0        Inglewood, CA   Male  University of California-Santa Barbara
# 1         Lewiston, MT   Male                Montana State University
# ...
